# %%
from circle import Circle
from rectangle import Rectangle

# %%
c1 = Circle(x=2,y=5,radius=10)
c2 = Circle(x=1,y=3,radius=15)
print(c2)
r1 = Rectangle(x=4,y=3,width=20,height=10)
print(r1)
c1.translate(4,12)
print(c1)
# Out:
# Cirkel på position (1, 3) med radie 15
# Rektangel på position (4, 3) med bredd 20 och höjd 10
# Cirkel på position (6, 17) med radie 10

# %%
try:
    rectangle2 = Rectangle(x=0,y=0,width=3, height=10) # raise TypeError
except TypeError as e:
    print(f"TypeError: {e}")

# %%
rectangle2.translate(10,-2)
print(rectangle2)
# Out:
# Rektangel på position (10, -2) med bredd 3 och höjd 10

# %%
try:
    rectangle2.translate(2,"eh")
except TypeError as e:
    print(f"TypeError: {e}")
# Out:
# TypeError: dx och dy måste vara nummer

# %%
c10 = Circle(x=0,y=0,radius=1)
print(c10.is_unit_circle())
c10.translate(2,4)
print(c10)
# Out:
# True
# Cirkel på position (2, 4) med radie 1

# %%
try:
    c20 = Circle(x=20,y=20,radius=-1)   
except ValueError as e:
    print(f"ValueError:{e}")
# Out:
# ValueError:Radius måste vara positiv

# %%
r24 = Rectangle(x=0,y=0,height=20,width=20)
c23 = Circle(x=0,y=2,radius=1)
r24==c23
# Out:
# False
